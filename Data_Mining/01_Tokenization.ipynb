# %% [markdown]
# ## 1. 형태소분석 : NLTK

# %%
#nltk 설치하기
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\hj\anaconda3\lib\site-packages (3.8.1)
# Requirement already satisfied: click in c:\users\hj\anaconda3\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\hj\anaconda3\lib\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\hj\anaconda3\lib\site-packages (from nltk) (2023.10.3)
# Requirement already satisfied: tqdm in c:\users\hj\anaconda3\lib\site-packages (from nltk) (4.66.4)
# Requirement already satisfied: colorama in c:\users\hj\anaconda3\lib\site-packages (from click->nltk) (0.4.6)

# %%
#nltk 실행하기
import nltk
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\hj\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
#샘플 텍스트
text = 'The little yellow dog barked at the Persian cat'

# %% [markdown]
# ##### ♦️1. 실습예제
#   - 명사만 추출하는 define 함수를 만들어보자!

# %% [markdown]
# ### 2.1. NLTK 불용어 사용하기

# %% [markdown]
# ### 2.2 소문자변환

# %% [markdown]
# ##### ♦️2. 실습예제
#   - 영어 불용어 적용 명사 define 만들기

# %% [markdown]
# ## 2. 형태소분석 : Konlpy

# %%
## 코랩 konlpy 실행
# !curl -s https://raw.githubusercontent.com/teddylee777/machine-learning/master/99-Misc/01-Colab/mecab-colab.sh | bash

# %%
from konlpy.tag import Okt
okt=Okt()

# %% [markdown]
# ##### ♦️3. 실습예제
#   - 한국어 불용어 적용된 명사/형용사/동사를 추출하는 define 만들기

# %% [markdown]
# ## 3. 형태소분석 : Kiwi

# %%
# !pip install kiwipiepy
# Out:
# Requirement already satisfied: kiwipiepy in c:\users\hj\anaconda3\lib\site-packages (0.18.0)
# Requirement already satisfied: kiwipiepy-model<0.19,>=0.18 in c:\users\hj\anaconda3\lib\site-packages (from kiwipiepy) (0.18.0)
# Requirement already satisfied: numpy<2 in c:\users\hj\anaconda3\lib\site-packages (from kiwipiepy) (1.26.4)
# Requirement already satisfied: tqdm in c:\users\hj\anaconda3\lib\site-packages (from kiwipiepy) (4.66.4)
# Requirement already satisfied: colorama in c:\users\hj\anaconda3\lib\site-packages (from tqdm->kiwipiepy) (0.4.6)

# %%
from kiwipiepy import Kiwi
kiwi = Kiwi()

# %% [markdown]
# ### 3.1 kiwi 불용어 사전 다루기

# %% [markdown]
# ### 3.2 kiwi 띄어쓰기 및 문장 분리
